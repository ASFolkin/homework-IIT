# %% [markdown]
# #<font size="6" color="black" face="Times"> <b>5. Ход работы</b></font><a name = 'part5'>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;5.1. Установка git</b></font><a name = 'part51'>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# &emsp;Уставливаем с официального сайта Git for Windows.<br>
# &emsp;Будем использоывть Git Bash, он эмулирует unix-подобную среду. В Git Bash доступны многие удобные утилиты, которых нет в Git CMD.<br>
# </div></font>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;5.2. Создание локального репозитория</b></font><a name = 'part52'>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# &emsp;Переходим в выбранную директорию классической командой `cd` и создаём репозиторий командой `git init`.<br>
# </div></font>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>&emsp;5.3. Добавление файла отчета в GIT</b></font><a name = 'part53'>
